# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image in grayscale
img = cv2.imread('red-apple.webp', cv2.IMREAD_GRAYSCALE)

# Apply Canny Edge Detection
edges = cv2.Canny(img, 100, 200)

# Display results
plt.figure(figsize=(10,5))
plt.subplot(1,2,1), plt.imshow(img, cmap='gray'), plt.title('Original')
plt.subplot(1,2,2), plt.imshow(edges, cmap='gray'), plt.title('Canny Edges')
plt.show()

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow  # ✅ Import for Colab

# Load image in grayscale
img = cv2.imread('image.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Harris Corner Detector
gray = np.float32(gray)
harris_corners = cv2.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)

# Mark detected corners in red
img[harris_corners > 0.01 * harris_corners.max()] = [0, 0, 255]

# ✅ Show image with detected corners in Colab
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-ccd977a910a9> in <cell line: 0>()
#       5 # Load image in grayscale
#       6 img = cv2.imread('image.jpg')
# ----> 7 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       8
#       9 # Apply Harris Corner Detector
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# Load image in grayscale
img = cv2.imread('red-apple.webp', cv2.IMREAD_GRAYSCALE)

# Initialize SIFT detector
sift = cv2.SIFT_create()

# Detect keypoints
keypoints, descriptors = sift.detectAndCompute(img, None)

# Draw keypoints
img_sift = cv2.drawKeypoints(img, keypoints, None)

# Show image with keypoints in Colab
cv2_imshow(img_sift)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-110267005100> in <cell line: 0>()
#      12
#      13 # Show image with keypoints in Colab
# ---> 14 cv2_imshow(img_sift)
#
# NameError: name 'cv2_imshow' is not defined

# %%
# Load image in grayscale
img = cv2.imread('red-apple.webp', cv2.IMREAD_GRAYSCALE)

# Initialize ORB detector
orb = cv2.ORB_create()

# Detect keypoints
keypoints, descriptors = orb.detectAndCompute(img, None)

# Draw keypoints
img_orb = cv2.drawKeypoints(img, keypoints, None)

# Show image with keypoints in Colab
cv2_imshow(img_orb)
# Out:
# <PIL.Image.Image image mode=RGB size=612x612>

# %%
# Load image in grayscale
img = cv2.imread('red-apple.webp', cv2.IMREAD_GRAYSCALE)

# Initialize SIFT detector
sift = cv2.SIFT_create()

# Detect keypoints
keypoints, descriptors = sift.detectAndCompute(img, None)

# Draw keypoints
img_sift = cv2.drawKeypoints(img, keypoints, None)

# Show image with keypoints in Colab
cv2_imshow(img_sift)
# Out:
# <PIL.Image.Image image mode=RGB size=612x612>

# %%
# Load image in grayscale
img = cv2.imread('red-apple.webp')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Harris Corner Detector
gray = np.float32(gray)
harris_corners = cv2.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)

# Mark detected corners in red
img[harris_corners > 0.01 * harris_corners.max()] = [0, 0, 255]

# Show image with detected corners in Colab
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x612>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# 📌 Step 1: Upload Image Manually in Colab (if needed)
uploaded = files.upload()

# 📌 Step 2: Load the Image in Grayscale
img = cv2.imread('red-apple.webp')

# Check if the image loaded correctly
if img is None:
    print("Error: Image not found. Please upload the correct file.")
else:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # 📌 Step 3: Apply Harris Corner Detection
    gray = np.float32(gray)
    harris_corners = cv2.cornerHarris(gray, blockSize=2, ksize=3, k=0.04)

    # 📌 Step 4: Mark Detected Corners in Red
    img[harris_corners > 0.01 * harris_corners.max()] = [0, 0, 255]

    # 📌 Step 5: Display the Image with Detected Corners
    cv2_imshow(img)
# Out:
#      <input type="file" id="files-b8c18c1a-6222-448c-ac94-fa38192f45ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8c18c1a-6222-448c-ac94-fa38192f45ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
